# %%
from sys import maxsize

# %% [markdown]
# # Create function

# %%
def traveling_salesman_function(graph, s):

# %%
### define graph
graph = [[0,10,15,20], [10,0,35,25], [15,35,0,30], [20,25,30,0]]
s = 0  # starting node

# %%
traveling_salesman_function(graph, s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 traveling_salesman_function(graph, s)
#
# NameError: name 'traveling_salesman_function' is not defined
