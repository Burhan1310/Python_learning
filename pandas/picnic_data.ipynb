# %%
import pandas as pd
df = pd.read_csv('picnic.csv')
df[df["Session :"]=="2019-2020"]
# Out:
#            Timestamp                   Name: Phone Number :  Session :  \
# 2    12/4/2023 21:06       Abdullah Al Noman   01799-102356  2019-2020
# 4    12/4/2023 22:09                   Sayed     1793348422  2019-2020
# 5    12/4/2023 21:42            Miad Bhuiyan     1902308728  2019-2020
# 8    12/4/2023 21:51           ?????? ??????     1701373936  2019-2020
# 10   12/4/2023 21:54       Yeasir Arafat Zim     1787368159  2019-2020
# 14   12/4/2023 21:57             Nasif Hasan     1797436871  2019-2020
# 15   12/4/2023 21:58      Md Hemayet Hossain     1760688361  2019-2020
# 16   12/4/2023 22:00         Md . Abdur Rouf     1959110408  2019-2020
# 21   12/4/2023 22:15         Tahsina yeasmin     1729807797  2019-2020
# 32   12/4/2023 23:31                  Burhan     1795952953  2019-2020
# 34   12/4/2023 23:41                   Sumon     1626483031  2019-2020
# 35   12/4/2023 23:44             Ahsan Habib     1836732385  2019-2020
# ...

# %%
df[['Name', 'session']][df.session=='2019-2020']
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df[['Name', 'session']][df.session=='2019-2020']
#       2 df
#
# File G:\Anaconda\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File G:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
# ...

# %%
ndf = df.query("session=='2019-2020'")["Name"]
ndf
# Out:
# 0           Abdullah Al Noman
# 2                       Sayed
# 3                Miad Bhuiyan
# 6               আরাফাত হোসাইন
# 8           Yeasir Arafat Zim
# 12                Nasif Hasan
# 13         Md Hemayet Hossain
# 14            Md . Abdur Rouf
# 19            Tahsina yeasmin
# 30                     Burhan
# 32                      Sumon
# 33                Ahsan Habib
# 34       Ashraful Alam Talash
# 38         Chayon Datta Utsho
# 41         Md. Ashikur Rahman
# 46         Sourav Chakraborty
# 51               Rofeya Hamid
# 52        Rokeya Sultana Asha
# 54         Nusrat Jahan Sonda
# 55                      Afrin
# 56         mst. suraiya akter
# 62                    Ibrahim
# 63         Hazrat Shah Showon
# 71                 Afsana mim
# 97          Anjuman Ara Oishe
# 98     Sajiatun Jannat Chhowa
# 99          Mst. Amina Yasmin
# 106             Rajone Khatun
# 107           Sumaiya zannath
# Name: Name, dtype: object

# %%
type(df.session)
# Out:
# pandas.core.series.Series

# %%
df.query("session=='2020-2021'")["Name"]
# Out:
# 28         ISHRAK ZAHAN SHEMANTO
# 35            Md. Shahjada Sajid
# 45               MD JULFIKAR ALI
# 64          Kazi Md Zubaer Ahmad
# 65                          Rony
# 66             Israt Jahan Bithi
# 76     Md. Ashiqur Rahman Sompod
# 77                         Arnob
# 82              Mst. Sadia Akter
# 85                  Indrani Saha
# 86            Sharmishtha Biswas
# 87                 Farzana Akter
# 88             Md. Saidur Rahman
# 89                  Halima Akter
# 90              Sadia Afrin Kumu
# 91           Kumari Sraboni Rani
# 93                Taeefa Farhana
# 100             Rafiqunnisa Roma
# 109           Md. Sazidur Rahman
# 110                       SHIHAB
# 128          Minhuz Taznim Himel
# Name: Name, dtype: object

# %%
df.query("session=='2022-2023'")["Name"]
# Out:
# 7            MD. ALTAF HOSSAIN.
# 9               Md. Fahim Azmol
# 10                     Md.Sonju
# 11                   Md Al Riad
# 15               Mongmycha Chak
# 16        Mst. Jannatul Ferdous
# 17              Mushfikur Rahim
# 18          Jobaida Nasrin Dola
# 20          Nure Jannath Ananna
# 21            Samia khan Sristy
# 22                  Maori Haque
# 23     Syeda Fahmida Hasan Fiza
# 24           Marzia Akter Mukti
# 26          Arzu Mohammad Rizvi
# 29             Misnu Al Asnawai
# 37             Md. Abir Hossain
# 42           Israt Jahan Rajoni
# 69      MD Rabiul Islam (Robin)
# 79                 Fahim Sarker
# 80               Naim Siddiquee
# 81                 Nazmul Hasan
# 92      Md sadiqur rahman Zihad
# 103                    CHONCHOL
# 111         Rakibul Islam Rakib
# 112             Sabyasachi sana
# 113       Mst.Akia Tahsin Kakon
# 114              Md Nasir Uddin
# 115        Shadikur Rahman Emon
# 116                Sadman Zaeed
# ...

# %%
df.query("session=='2021-2022'")["Name"]
# Out:
# 1              Tanvirul Hoque Akib
# 4             Sakeef Mahmud Foysal
# 5                   Md.Shamim Reza
# 25                 MD HRIDOY AHMED
# 36               Abdullah al sabet
# 39                   Tajbir Hossen
# 40               Sayed Nahid Kabir
# 43              Md. Moshiur Rahman
# 44                  Md. Siam Hasan
# 47                            Riad
# 48              Md Israfil Hossain
# 49                            Abhi
# 50     kazi eahteshamul haque apon
# 53                    A.H.M Junaed
# 57                  Jakia Tabassum
# 58                      Abu Ubaida
# 59                    Mehedi Hasan
# 67                Shahriar Hossain
# 68             Fawziya Farzana Mim
# 70       Mst. Suravi Sultana Shova
# 72          Samiul Quoreshi Sourav
# 73                    Joyeta Modak
# 74                   Meherin Akter
# 75                   Tanjima Islam
# 78                           Nafis
# 84            Naimur Rahman Durjoy
# 94        Md.Musfiqur Rahaman Rana
# ...

# %%
df.query("session=='2018-2019'")["Name"]
# Out:
# 27     Shahriar Kajol joy
# 31          Ikbal Hossain
# 60         Sabrina Parvin
# 61        Tasnia Tabassum
# 101                sowrov
# 108            Atik Hasan
# Name: Name, dtype: object

# %%
df.query("Payment=='Bkash (205 tk)'")["session"]
# Out:
# 38     2019-2020
# 51     2019-2020
# 69     2022-2023
# 104    2021-2022
# 108    2018-2019
# 110    2020-2021
# 118    2021-2022
# 123    2021-2022
# 124    2021-2022
# 125    2021-2022
# 129    2020-2021
# 130    2020-2021
# Name: session, dtype: object

# %%
df.query("Payment=='Nagad (205 tk)'")["Name"]
# Out:
# 44         Md. Siam Hasan
# 109    Md. Sazidur Rahman
# 131         Afroza khatun
# Name: Name, dtype: object

# %%
df.query("Payment=='Bkash (205 tk)'")["Name"]
# Out:
# 38          Chayon Datta Utsho
# 51                Rofeya Hamid
# 69     MD Rabiul Islam (Robin)
# 104             Shariha Shenty
# 108                 Atik Hasan
# 110                     SHIHAB
# 118        Nishat Nuzhat Kabbo
# 123        Md.Hasan Ali Shaikh
# 124                      Naeem
# 125    MD.Raiyanur Rahman Naim
# 129           MD.Rabbiul Titas
# 130           মো শাহিনুর রহমান
# Name: Name, dtype: object
